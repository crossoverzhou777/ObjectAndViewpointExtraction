# %%
                                                                                           #导包
import numpy as np
import jieba
import jieba.posseg as jp
import re

# import pandas as pd
# from snownlp import SnowNLP
# from scipy.linalg import norm
# from fasttext.FastText import load_model


# #加载词向量模型，这里使用的是7.63G的中文词向量模型
# fasttext_model = load_model('cc.zh.300.bin')


#词性添加框
jieba.add_word("傻逼",tag="n")
jieba.add_word("不是",tag="v")
jieba.add_word("不好",tag="a")
jieba.add_word("太渣了",tag="a")
jieba.add_word("再进",tag="v")
jieba.add_word("打钱",tag="v")
jieba.add_word("更新",tag="v")
jieba.add_word("挺好",tag="a")
jieba.add_word("太棒了",tag="a")
jieba.add_word("应用",tag="n")
jieba.add_word("挺不错",tag="a")
jieba.add_word("五星",tag="a")
jieba.add_word("太差",tag="a")
jieba.add_word("拼多多",tag="n")
jieba.add_word("点进去",tag="v")
jieba.add_word("抖音",tag="n")
jieba.add_word("好用",tag="a")
jieba.add_word("快手",tag="n")
jieba.add_word("过来",tag="v")
jieba.add_word("差评",tag="a")
jieba.add_word("短视频",tag="n")
jieba.add_word("一样",tag="a")
jieba.add_word("网页端",tag="n")
jieba.add_word("搜东西",tag="vn")
jieba.add_word("断网",tag="vn")
jieba.add_word("点",tag="v")
jieba.add_word("设置",tag="v")
jieba.add_word("还行",tag="a")
jieba.add_word("绝望",tag="a")
jieba.add_word("作业帮",tag="n")
jieba.add_word("收听广播",tag="vn")
jieba.add_word("好玩",tag="a")
jieba.add_word("小红书",tag="nr")
jieba.add_word("明白",tag="v")
jieba.add_word("为毛",tag="e")
jieba.add_word("最新",tag="a")
jieba.add_word("耗钱",tag="vn")
jieba.add_word("耗时",tag="vn")
jieba.add_word("不错滴",tag="an")
jieba.add_word("用",tag="v")
jieba.add_word("气死",tag="v")
jieba.add_word("很快",tag="a")
jieba.add_word("分",tag="v")
jieba.add_word("都",tag="p")
jieba.add_word("冷门",tag="a")
jieba.add_word("花屏",tag="a")
jieba.add_word("乐视",tag="ns")
jieba.add_word("给力",tag="a")
jieba.add_word("无法",tag="a")
jieba.add_word("骁龙",tag="ns")
jieba.add_word("有点",tag="a")
jieba.add_word("游戏",tag="n")
jieba.add_word("可以",tag="a")
jieba.add_word("自启",tag="v")
jieba.add_word("西瓜视频",tag="nz")
jieba.add_word("对了",tag="a")
jieba.add_word("卡顿",tag="a")
jieba.add_word("全面",tag="a")
jieba.add_word("牛逼",tag="a")
jieba.add_word("多",tag="a")
jieba.add_word("下不了",tag="a")



# 获取分词列表和词性列表
def To_segment(text):
    segmen_list = jp.lcut(text)
    segment_list  =[]
    for i in segmen_list:
        for j in i:
            segment_list.append(j)
    segment = []
    chara = []
    for k in range(0,len(segment_list)):
        if k % 2 == 0:
            segment.append(segment_list[k])
        else:
            chara.append(segment_list[k])
    # print(chara)
    # print(segment)
    # print("分词结束============================================================")
    return chara,segment

#将一个长评论按照标点符号来进行切分
def split_segment(sentence):
    a = ['！','。','？','；','，',',']
    jud = [i for i in sentence if i in a]
    print(jud)
    temp = re.split("[，！。？. …  ]",sentence.strip())
    return temp


#去除对于语义表达无关的词性
def del_no_relative_WC(chara,segment):
    junk = ['ul', 'zg','r','uj','t','x','eng','q','f']
    newSeg = []
    newChara = []
    count = 0
    for i in chara:
        if i not in junk:
            newSeg.append(segment[count])
            newChara.append(i)
        count += 1
    # print(newSeg)
    # print(newChara)
    # print("删除无关词结束============================================================")

    return  newChara,newSeg
#获取核心表达含义，返回词性，词汇和位置，接受的参数是词性和分词列表
def get_chara_loc_meaning(chara,segment):
    main = []
    seg1 = []
    localtion = []
    for i in range(0,len(chara)):
        if chara[i] == 'n'  or chara[i] == 'nt' or chara[i] == 'nz':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'v' or chara[i] == 'vn':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'a' or chara[i] == 'an':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'd':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'p':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'df':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'b':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'm':
            main.append(chara[i])
            localtion.append(i)
        else:
            continue
    for j in localtion:
        seg1.append(segment[j])
    return main,seg1,localtion

def get_ob_op(chara,seg,software):
    consequence = []
    if len(chara) == 0:
        return consequence
    elif chara[0] == "a":
        ob = software
        op = ''
        for i in range(0,len(seg)):
            op = op + seg[i]
        consequence.append(ob)
        consequence.append(op)
        return consequence
    #这种情况是分词列表中没有名词的情况，用软件名用作评价对象
    elif 'n' not in chara and 'v' in chara or 'a' in chara and chara[1] != 'a':
        ob = software
        consequence.append(ob)
        op = ''
        for word in seg:
            op = op + word
        consequence.append(op)
        return consequence
    #这种是连续出现开头名词的情况
    elif chara[0] == 'n' and len(chara) != 1:
        ob = ''
        for i in range(0,len(chara)):
            if chara[i] == 'n':
                ob = ob + seg[i]
            else:
                flag = i
                break
        op = ''
        for j in range(flag,len(chara)):
            op = op + seg[j]
        consequence.append(ob)
        consequence.append(op)
        return consequence

    elif chara[0] == 'n' and len(chara) == 1:
        ob = software
        op = seg[0]
        consequence.append(ob)
        consequence.append(op)
        return consequence

    elif chara[0] != "n" and chara[0] == "v" and chara[0] != 'nr':
        flag = 0
        for i in range(0,len(chara)):
            if chara[i] != "n" or chara[i] != "v":
                flag = flag + 1
            else:
                break
        if flag >= 2:
            ob = software
            op = ''
            for j in range(0, len(chara)):
                op = op + seg[j]
            consequence.append(ob)
            consequence.append(op)
        return consequence

    elif chara[0] == 'nr' and 'v' not in chara and 'a' not in chara:
        flag = 0
        for i in range(0, len(chara)):
            if chara[i] == 'nr':
                flag = flag + 1
        if flag == len(chara):
            return consequence

    elif chara[0] =='n' and chara[1] == 'a':
        ob = seg[0]
        op = ''
        for i in range(1,len(chara)):
            op = op + seg[i]
        consequence.append(ob)
        consequence.append(op)
        return consequence

    else:
        return consequence
def get_chara_loc_meaning1(chara,segment):
    main = []
    seg1 = []
    localtion = []
    for i in range(0,len(chara)):
        if chara[i] == 'n'  or chara[i] == 'nt' or chara[i] == 'nz':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'v' or chara[i] == 'vn':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'a' or chara[i] == 'an':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'd':
            main.append(chara[i])
            localtion.append(i)
        else:
            continue
    for j in localtion:
        seg1.append(segment[j])
    return main,seg1,localtion

def get_ob_op_1(chara,seg,software):
    long = len(chara)
    consequence = []
    if long == 0:
        return consequence

    elif long == 1:
        if chara == ['a']:
            ob = software
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        else:
            return consequence
    elif long == 2:
        if chara == ['n','v']:
            ob = chara[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n','a']:
            ob = chara[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v", "a"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v", "n"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["a", "n"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["a", "v"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v",'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["n",'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["n",'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence










if __name__ == "__main__":

    sentencce = '总是在后台自启'
    text_list = split_segment(sentencce)
    print(text_list)
    print("=========================")
    ob_op_list = []
    for text in text_list:
        #对评论进行分词
        chara,seg = To_segment(text)
        print(chara)
        print(seg)
        #去除无关用词
        chara,seg = del_no_relative_WC(chara,seg)
        #得到核心用词
        chara,seg,localtion = get_chara_loc_meaning(chara, seg)
        print(chara)
        print(seg)
        print(localtion)
        print("==============================")
        ob_op = get_ob_op(chara,seg,"支付宝")
        print(ob_op)
        if len(ob_op) != 0:
            ob_op_list.append(ob_op)
    #这部分是出去完全一样的评价对象和评价观点
    new_ob_op_list = []
    for op_ob in ob_op_list:
        if op_ob not in new_ob_op_list:
            new_ob_op_list.append(op_ob)
    #输出抽取到的评价对象和评价观点
    print(new_ob_op_list)
# Out:
# []
# ['总是在后台自启']
# ...
# ['c', 'p', 'n', 'v']
# ['总是', '在', '后台', '自启']
# ['p', 'n', 'v']
# ['在', '后台', '自启']
# [1, 2, 3]
# ...
# []
# []

# %%
#导包
import numpy as np
import jieba
import jieba.posseg as jp
import re

# import pandas as pd
# from snownlp import SnowNLP
# from scipy.linalg import norm
# from fasttext.FastText import load_model


# #加载词向量模型，这里使用的是7.63G的中文词向量模型
# fasttext_model = load_model('cc.zh.300.bin')


#词性添加框
jieba.add_word("傻逼",tag="n")
jieba.add_word("不是",tag="v")
jieba.add_word("不好",tag="a")
jieba.add_word("太渣了",tag="a")
jieba.add_word("再进",tag="v")
jieba.add_word("打钱",tag="v")
jieba.add_word("更新",tag="v")
jieba.add_word("挺好",tag="a")
jieba.add_word("太棒了",tag="a")
jieba.add_word("应用",tag="n")
jieba.add_word("挺不错",tag="a")
jieba.add_word("五星",tag="a")
jieba.add_word("太差",tag="a")
jieba.add_word("拼多多",tag="n")
jieba.add_word("点进去",tag="v")
jieba.add_word("抖音",tag="n")
jieba.add_word("好用",tag="a")
jieba.add_word("快手",tag="n")
jieba.add_word("过来",tag="v")
jieba.add_word("差评",tag="a")
jieba.add_word("短视频",tag="n")
jieba.add_word("一样",tag="a")
jieba.add_word("网页端",tag="n")
jieba.add_word("搜东西",tag="vn")
jieba.add_word("断网",tag="vn")
jieba.add_word("点",tag="v")
jieba.add_word("设置",tag="v")
jieba.add_word("还行",tag="a")
jieba.add_word("绝望",tag="a")
jieba.add_word("作业帮",tag="n")
jieba.add_word("收听广播",tag="vn")
jieba.add_word("好玩",tag="a")
jieba.add_word("小红书",tag="nr")
jieba.add_word("明白",tag="v")
jieba.add_word("为毛",tag="e")
jieba.add_word("最新",tag="a")
jieba.add_word("耗钱",tag="vn")
jieba.add_word("耗时",tag="vn")
jieba.add_word("不错滴",tag="an")
jieba.add_word("用",tag="v")
jieba.add_word("气死",tag="v")
jieba.add_word("很快",tag="a")
jieba.add_word("分",tag="v")
jieba.add_word("都",tag="p")
jieba.add_word("冷门",tag="a")
jieba.add_word("花屏",tag="a")
jieba.add_word("乐视",tag="ns")
jieba.add_word("给力",tag="a")
jieba.add_word("无法",tag="a")
jieba.add_word("骁龙",tag="ns")
jieba.add_word("有点",tag="a")
jieba.add_word("游戏",tag="n")
jieba.add_word("可以",tag="a")
jieba.add_word("自启",tag="v")
jieba.add_word("西瓜视频",tag="nz")
jieba.add_word("对了",tag="a")
jieba.add_word("卡顿",tag="a")
jieba.add_word("全面",tag="a")
jieba.add_word("啊啊啊",tag="e")
jieba.add_word("牛逼",tag="a")
jieba.add_word("多",tag="a")
jieba.add_word("下不了",tag="a")
jieba.add_word("root",tag="v")
jieba.add_word("换了系统",tag="vn")
jieba.add_word("棒",tag="a")
jieba.add_word("在用",tag="v")
jieba.add_word("好好",tag="a")
jieba.add_word("用",tag="v")
jieba.add_word("方便",tag="a")
jieba.add_word("使用",tag="v")
jieba.add_word("使用方便",tag="a")
jieba.add_word("很多",tag="a")
jieba.add_word("好多了",tag="a")
jieba.add_word("做到了",tag="a")
jieba.add_word("大忙",tag="n")
jieba.add_word("4星",tag="a")
jieba.add_word("浪费",tag="v")
jieba.add_word("流量费",tag="n")
jieba.add_word("安全隐患",tag="n")
jieba.add_word("老是",tag="d")
jieba.add_word("众多",tag="a")
jieba.add_word("我",tag="n")
jieba.add_word("小说迷",tag="n")
jieba.add_word("挺多的",tag="a")
jieba.add_word("美观",tag="a")
jieba.add_word("强烈推荐",tag="vn")
jieba.add_word("好看",tag="a")
jieba.add_word("顺手",tag="a")
jieba.add_word("很",tag="d")
jieba.add_word("同步",tag="a")
jieba.add_word("免费",tag="a")
jieba.add_word("齐全",tag="a")
jieba.add_word("大力",tag="d")
jieba.add_word("挺多",tag="a")
jieba.add_word("基本上",tag="d")
jieba.add_word("更新快",tag="a")
jieba.add_word("用了",tag="v")
jieba.add_word("好极了",tag="a")
jieba.add_word("我会",tag="v")
jieba.add_word("好慢",tag="a")





# 获取分词列表和词性列表
def To_segment(text):
    segmen_list = jp.lcut(text)
    segment_list  =[]
    for i in segmen_list:
        for j in i:
            segment_list.append(j)
    segment = []
    chara = []
    for k in range(0,len(segment_list)):
        if k % 2 == 0:
            segment.append(segment_list[k])
        else:
            chara.append(segment_list[k])
    # print(chara)
    # print(segment)
    # print("分词结束============================================================")
    return chara,segment

#将一个长评论按照标点符号来进行切分
def split_segment(sentence):
    a = ['！','。','？','；','，',',','~']
    jud = [i for i in sentence if i in a]
    print(jud)
    temp = re.split("[，！。？. … , ~]",sentence.strip())
    return temp


#去除对于语义表达无关的词性
def del_no_relative_WC(chara,segment):
    junk = ['ul', 'zg','r','uj','t','x','eng','q','f']
    newSeg = []
    newChara = []
    count = 0
    for i in chara:
        if i not in junk:
            newSeg.append(segment[count])
            newChara.append(i)
        count += 1
    # print(newSeg)
    # print(newChara)
    # print("删除无关词结束============================================================")

    return  newChara,newSeg
#获取核心表达含义，返回词性，词汇和位置，接受的参数是词性和分词列表



def get_chara_loc_meaning1(chara,segment):
    main = []
    seg1 = []
    localtion = []
    for i in range(0,len(chara)):
        if chara[i] == 'n'  or chara[i] == 'nt' or chara[i] == 'nz' or chara[i] == 'nr' or chara[i] == 'ns' :
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'v' or chara[i] == 'vn' or chara[i] == 'vg':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'a' or chara[i] == 'ad':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'a'  and i < len(chara) and chara[i+1] != 'a':
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'an'  :
            main.append(chara[i])
            localtion.append(i)
        elif chara[i] == 'an'  and i < len(chara) and chara[i+1] != 'an':
            main.append(chara[i])
            localtion.append(i)
        elif chara[len(chara)-1] == 'd':
            break
        elif chara[i] == 'd' and i < len(chara) and chara[i+1] != 'd':
            main.append(chara[i])
            localtion.append(i)
        else:
            continue
    for j in localtion:
        seg1.append(segment[j])
    return main,seg1,localtion

def get_ob_op_1(chara,seg,software):
    long = len(chara)
    consequence = []
    if long == 0:
        return consequence

    elif long == 1:
        if chara == ['a']:
            ob = software
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['nz']:
            ob = software
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v']:
            ob = software
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['vn']:
            ob = software
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        else:
            return consequence
    elif long == 2:
        if chara == ['n','v']:
            ob = seg[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n','a']:
            ob = seg[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v", "a"]:
            ob = seg[0]
            op = ''
            op = op  + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v", "n"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["a", "n"]:
            ob = seg[1]
            op = ''
            op = op + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["a", "v"]:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ["v",'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n','n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d','a']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v','nz']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v','nr']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d','v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d','n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d','nz']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['vn','v']:
            ob = seg[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'vn']:
            ob = seg[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['ad', 'a']:
            ob = software
            op = ''
            op = op + seg[0]+seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'a']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[1]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        else:
            return consequence
    elif long == 3:
        if chara == ['n', 'd', 'v']:
            ob = seg[0]
            op = ''
            op = op + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'a', 'v']:
            ob = software
            op = ''
            op = op + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'a', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'd', 'a']:
            ob = seg[0]
            op = ''
            op = op +  seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'd', 'v']:
            ob = software
            op = ''
            op = op + seg[0]+ seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'a']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'ad']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        #同一个分句但是有多个评价对象
        elif chara == ['n', 'a', 'a']:
            if seg[1] != '很':
                temporary = []
                ob1 = seg[0]
                op1 = ''
                op1 = op1 + seg[1]
                temporary.append(ob1)
                temporary.append(op1)
                consequence.append(temporary)
                temporary = []
                ob2 = seg[0]
                op2 = ''
                op2 = op2 + seg[2]
                temporary.append(ob2)
                temporary.append(op2)
                consequence.append(temporary)
                return consequence
            else:
                ob = seg[0]
                op = ''
                op = op + seg[1] + seg[2]
                consequence.append(ob)
                consequence.append(op)
                return consequence


        elif chara == ['a', 'd', 'a']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[1] + seg[2]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['d', 'a', 'a']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0] + seg[1]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[2]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['d', 'a', 'n']:
            ob = seg[2]
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'd', 'n']:
            ob = seg[0]
            op = ''
            op = op + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'a', 'n']:
            ob = seg[2]
            op = ''
            op = op + seg[0] + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['an', 'a', 'n']:
            temporary = []
            ob1 = seg[2]
            op1 = ''
            op1 = op1 + seg[0]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = seg[2]
            op2 = ''
            op2 = op2 + seg[1]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['v', 'n', 'n']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0] + seg[1]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[0] + seg[2]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['d', 'v', 'a']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'd', 'an']:
            ob = seg[0]
            op = ''
            op = op +  seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'nr']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'n', 'a']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'd', 'a']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1]+seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['nz', 'd', 'n']:
            ob = seg[0]
            op = ''
            op = op + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        else:
            return consequence
    elif long == 4:
        if chara == ['n', 'v', 'n', 'n']:
            ob = seg[0]
            op = ''
            op = op + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'd', 'v', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'a', 'v', 'a']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[1]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[3]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['a', 'n', 'a', 'a']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0] + seg[1]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[2] + seg[3]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        elif chara == ['n', 'n', 'v', 'n']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'a', 'd', 'd']:
            ob = seg[0]
            op = ''
            op = op + seg[1]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'v', 'd', 'a']:
            ob = seg[0]
            op = ''
            op = op + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'a', 'v']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'v', 'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'd', 'v', 'n']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'v', 'vn']:
            ob = software
            op = ''
            op = op + seg[0] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'v', 'nz']:
            ob = software
            op = ''
            op = op + seg[0] + seg[1] + seg[2]+ seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'd', 'a']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'v', 'a']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'n', 'a']:
            ob = software
            op = ''
            op = op + seg[0]+ seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'n', 'a']:
            ob = seg[0]+ seg[1] + seg[2]
            op = ''
            op = op + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'n', 'd', 'v']:
            ob = seg[0]+ seg[1]
            op = ''
            op = op + seg[2] +  seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'a', 'v', 'n']:
            ob = seg[2] + seg[3]
            op = ''
            op = op + seg[1] + seg[2]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'd', 'a', 'n']:
            ob = software
            op = ''
            op = op + seg[0]+ seg[1] + seg[2] + seg[3]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['a', 'v', 'v', 'v']:
            ob = software
            op = ''
            op = op +  seg[1] + seg[2] + seg[3] + seg[0]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        else:
            return consequence
    elif long == 5:
        if chara == ['v', 'n', 'n', 'a', 'a']:
            ob = seg[0] + seg[1] + seg[2]
            op = ''
            op = op + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'a', 'd', 'n']:
            ob = software
            op = ''
            op = op + seg[2] + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'd', 'vn', 'v']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'd', 'v', 'v']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'n', 'v', 'v', 'n']:
            ob = seg[0] + seg[1]
            op = ''
            op = op + seg[2] + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['n', 'd', 'v', 'd', 'n']:
            ob = seg[0]
            op = ''
            op = op + seg[1]+ seg[2] + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['d', 'v', 'n', 'v', 'v']:
            ob = seg[1] + seg[2]
            op = ''
            op = op + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
        elif chara == ['v', 'v', 'ns', 'v', 'v']:
            temporary = []
            ob1 = software
            op1 = ''
            op1 = op1 + seg[0] + seg[1] + seg[2]
            temporary.append(ob1)
            temporary.append(op1)
            consequence.append(temporary)
            temporary = []
            ob2 = software
            op2 = ''
            op2 = op2 + seg[3] + seg[4]
            temporary.append(ob2)
            temporary.append(op2)
            consequence.append(temporary)
            return consequence
        else:
            return consequence
    elif long == 6:
        if chara == ['d', 'v', 'a', 'a', 'a', 'n']:
            ob = seg[5]
            op = ''
            op = op + seg[3] + seg[4]
            consequence.append(ob)
            consequence.append(op)
            return consequence
    else:
        return consequence










if __name__ == "__main__":

    sentencce = '张清灵是大笨蛋'
    text_list = split_segment(sentencce)
    print(text_list)
    print("=========================")
    ob_op_list = []
    for text in text_list:
        #对评论进行分词
        chara,seg = To_segment(text)
        print(chara)
        print(seg)
        #去除无关用词
        chara,seg = del_no_relative_WC(chara,seg)
        #得到核心用词
        chara,seg,localtion = get_chara_loc_meaning1(chara, seg)
        print(chara)
        print(seg)
        print(localtion)
        print("==============================")
        ob_op = get_ob_op_1(chara,seg,"腾讯动漫")
        print(ob_op)
        if len(ob_op) != 0:
            if len(ob_op[0][0]) != 1 :
                for small in ob_op:
                    ob_op_list.append(small)
            else:
                if len(ob_op) != 0:
                    ob_op_list.append(ob_op)


    #这部分是出去完全一样的评价对象和评价观点
    new_ob_op_list = []
    for op_ob in ob_op_list:
        if op_ob not in new_ob_op_list:
            new_ob_op_list.append(op_ob)

    #输出抽取到的评价对象和评价观点
    print(new_ob_op_list)
# Out:
# []
# ['张清灵是大笨蛋']
# ...
# ['q', 'a', 'v', 'a', 'n']
# ['张', '清灵', '是', '大', '笨蛋']
# ['a', 'v', 'a', 'n']
# ['清灵', '是', '大', '笨蛋']
# [0, 1, 2, 3]
# ...
# []
# []
# []
# ['张清灵是大笨蛋']
# ...
# ['q', 'a', 'v', 'a', 'n']
# ['张', '清灵', '是', '大', '笨蛋']
# ['a', 'v', 'a', 'n']
# ['清灵', '是', '大', '笨蛋']
# [0, 1, 2, 3]
# ...
# []
# []
# []
# ['张清灵是大笨蛋']
# ...
# ['q', 'a', 'v', 'a', 'n']
# ['张', '清灵', '是', '大', '笨蛋']
# ['a', 'v', 'a', 'n']
# ['清灵', '是', '大', '笨蛋']
# [0, 1, 2, 3]
# ...
# []
# []
